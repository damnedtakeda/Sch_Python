# %%
# %pip install openai rich dotenv

Requirement already satisfied: openai in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (2.7.1)
Requirement already satisfied: rich in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (14.2.0)
Requirement already satisfied: dotenv in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (0.9.9)
Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from openai) (4.11.0)
Requirement already satisfied: distro<2,>=1.7.0 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from openai) (1.9.0)
Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from openai) (0.28.1)
Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from openai) (0.11.1)
Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from openai) (2.12.4)
Requirement already satisfied: sniffio in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from openai) (1.3.1)
Requirement already satisfied: tqdm>4 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from openai) (4.67.1)
Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from openai) (4.15.0)
Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from rich) (4.0.0)
Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\slesa\appdata\roaming\python\python313\site-packages (from rich) (2.19.2)
Requirement already satisfied: python-dotenv in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from dotenv) (1.2.1)
Requirement already satisfied: idna>=2.8 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
Requirement already satisfied: certifi in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
Requirement already satisfied: httpcore==1.* in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
Requirement already satisfied: h11>=0.16 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
Requirement already satisfied: mdurl~=0.1 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
Requirement already satisfied: annotated-types>=0.6.0 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
Requirement already satisfied: pydantic-core==2.41.5 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
Requirement already satisfied: colorama in c:\users\slesa\appdata\local\programs\python\python313\lib\site-packages (from tqdm>4->openai) (0.4.6)
Note: you may need to restart the kernel to use updated packages.

[notice] A new release of pip is available: 25.0.1 -> 25.3
[notice] To update, run: python.exe -m pip install --upgrade pip

from rich import print
from rich.panel import Panel
from rich.console import Console
from rich.markdown import Markdown
from rich.theme import Theme

console = Console()

import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv("key.env")
api_key = os.getenv("API_KEY")
url = "https://foundation-models.api.cloud.ru/v1"

custom_theme = Theme({
    "markdown.h1": "#b38dd9",
    "rule.line": "#452268"                  
})

console = Console(theme=custom_theme)

messages = [
    {
        "role": "system", 
        "content": "Ты AI-ассистент. Отвечай на вопросы понятно и развернуто."
    }
]

console.print(
    Panel(
        "Привет! Я ваш AI-помощник. Чем могу помочь?",
        title="[#f3efe8]Чат-бот[/#f3efe8]",
        border_style="#f3efe8"
    )
)

while True: 
    
    user_input = input("Вы: ")

    console.print(f"[#b38dd9]Вы:[/#b38dd9] {user_input}")

    if user_input.lower() in ["/exit"]:
        console.print(
            Panel(
                "До свидания! Было приятно пообщаться.",
                title="[#ae1f1f]Сеанс завершен[/#ae1f1f]",
                border_style="red"
            )
        )
        break

    elif user_input.lower() in ["/clear"]:
        messages = [messages[0]] 
        console.print("[#336659]System:[/#336659] История очищена.")

    elif user_input.lower() in ["/system"]:
        console.print("[#336659]System:[/#336659] Введите новое системное сообщение...")
        new_system = input()
        if new_system:
            messages[0]["content"] = new_system
            console.print("[#336659]System:[/#336659] Системное сообщение обновлено.")
       
    else:
        messages.append({
            "role": "user",
            "content": user_input   
        })
        
        try:
            response = client.chat.completions.create(
                model="Qwen/Qwen3-Next-80B-A3B-Instruct",
                max_tokens=500,
                temperature=0.7,
                messages=messages
            )
            
            llm_answer = response.choices[0].message.content
            
            console.print(
                Panel(
                    llm_answer,
                    title="[#f3efe8]Чат-бот[/#f3efe8]",
                    border_style="#f3efe8"
                )
            )
            
            messages.append({
                "role": "assistant",
                "content": llm_answer
            })
            
        except Exception as e:
            console.print(f"[red]Ошибка: {e}[/red]")
