# %% [markdown]
# <a href="https://colab.research.google.com/github/damnedtakeda/Sch_Python/blob/main/finetune_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Fine-tuning T-one with 🤗 Transformers**

# %% [markdown]
# This notebook provides the fine-tuning recipe for `T-one` pretrained acoustic model.
#
# ### Installation
# To work with audio files, you may need to install libsndfile manually. Please refer to the [SoundFile](https://python-soundfile.readthedocs.io/en/0.13.1/#installation) installation documentation for details.
#
# Install the dependencies:
# ```bash
# poetry install -E finetune
# ```
#
# Select Python kernel with the installed dependencies.

# %%
# !git clone https://github.com/voicekit-team/T-one t-one
# !pip install poetry
# !pip install git+https://github.com/voicekit-team/T-one.git
# !cd t-one && poetry install -E finetune
# !pip install -U datasets accelerate transformers evaluate jiwer
# !pip install torchcodec protobuf==5.29.3
# Out:
# Cloning into 't-one'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 120 (delta 36), reused 104 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 1.53 MiB | 30.04 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# Requirement already satisfied: poetry in /usr/local/lib/python3.12/dist-packages (2.2.1)
# Requirement already satisfied: build<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from poetry) (1.4.0)
# Requirement already satisfied: cachecontrol<0.15.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (0.14.4)
# Requirement already satisfied: cleo<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from poetry) (2.1.0)
# Requirement already satisfied: dulwich<0.25.0,>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from poetry) (0.24.10)
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from poetry) (2.21.2)
# Requirement already satisfied: findpython<0.8.0,>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from poetry) (0.7.1)
# Requirement already satisfied: installer<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from poetry) (0.7.0)
# Requirement already satisfied: keyring<26.0.0,>=25.1.0 in /usr/local/lib/python3.12/dist-packages (from poetry) (25.7.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from poetry) (25.0)
# Requirement already satisfied: pbs-installer<2026.0.0,>=2025.1.6 in /usr/local/lib/python3.12/dist-packages (from pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (2025.12.17)
# Requirement already satisfied: pkginfo<2.0,>=1.12 in /usr/local/lib/python3.12/dist-packages (from poetry) (1.12.1.2)
# Requirement already satisfied: platformdirs<5,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from poetry) (4.5.1)
# Requirement already satisfied: poetry-core==2.2.1 in /usr/local/lib/python3.12/dist-packages (from poetry) (2.2.1)
# Requirement already satisfied: pyproject-hooks<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from poetry) (1.2.0)
# Requirement already satisfied: requests<3.0,>=2.26 in /usr/local/lib/python3.12/dist-packages (from poetry) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from poetry) (1.0.0)
# Requirement already satisfied: shellingham<2.0,>=1.5 in /usr/local/lib/python3.12/dist-packages (from poetry) (1.5.4)
# Requirement already satisfied: tomlkit<1.0.0,>=0.11.4 in /usr/local/lib/python3.12/dist-packages (from poetry) (0.13.3)
# Requirement already satisfied: trove-classifiers>=2022.5.19 in /usr/local/lib/python3.12/dist-packages (from poetry) (2025.12.1.14)
# Requirement already satisfied: virtualenv>=20.26.6 in /usr/local/lib/python3.12/dist-packages (from poetry) (20.36.1)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.12/dist-packages (from cachecontrol<0.15.0,>=0.14.0->cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (1.1.2)
# Requirement already satisfied: filelock>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (3.20.3)
# Requirement already satisfied: crashtest<0.5.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from cleo<3.0.0,>=2.1.0->poetry) (0.4.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from cleo<3.0.0,>=2.1.0->poetry) (3.14.3)
# Requirement already satisfied: urllib3>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from dulwich<0.25.0,>=0.24.0->poetry) (2.5.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring<26.0.0,>=25.1.0->poetry) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring<26.0.0,>=25.1.0->poetry) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring<26.0.0,>=25.1.0->poetry) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring<26.0.0,>=25.1.0->poetry) (4.3.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring<26.0.0,>=25.1.0->poetry) (6.0.1)
# Requirement already satisfied: httpx<1,>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (0.28.1)
# Requirement already satisfied: zstandard>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.26->poetry) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.26->poetry) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.26->poetry) (2025.11.12)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.26.6->poetry) (0.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.27.0->pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.27.0->pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.27.0->pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (0.16.0)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.12/dist-packages (from SecretStorage>=3.2->keyring<26.0.0,>=25.1.0->poetry) (43.0.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring<26.0.0,>=25.1.0->poetry) (10.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring<26.0.0,>=25.1.0->poetry) (2.0.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.27.0->pbs-installer[download,install]<2026.0.0,>=2025.1.6->poetry) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring<26.0.0,>=25.1.0->poetry) (2.23)
# Collecting git+https://github.com/voicekit-team/T-one.git
#   Cloning https://github.com/voicekit-team/T-one.git to /tmp/pip-req-build-_h1azd3j
#   Running command git clone --filter=blob:none --quiet https://github.com/voicekit-team/T-one.git /tmp/pip-req-build-_h1azd3j
#   Resolved https://github.com/voicekit-team/T-one.git to commit 3c5b6c015038173840e62cea99e10cdb1c759116
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.36.0)
# Requirement already satisfied: kenlm<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.3.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17.3 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (1.26.4)
# Requirement already satisfied: onnxruntime<2.0.0,>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (1.23.2)
# Requirement already satisfied: pyctcdecode<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (1.2.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (25.9.23)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (1.14.0)
# Requirement already satisfied: pygtrie<3.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from pyctcdecode<1.0.0,>=0.2.0->tone==0.1.0) (2.5.0)
# Requirement already satisfied: hypothesis<7,>=6.14 in /usr/local/lib/python3.12/dist-packages (from pyctcdecode<1.0.0,>=0.2.0->tone==0.1.0) (6.150.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from hypothesis<7,>=6.14->pyctcdecode<1.0.0,>=0.2.0->tone==0.1.0) (2.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (1.3.0)
# Building wheels for collected packages: tone
#   Building wheel for tone (pyproject.toml) ... done
#   Created wheel for tone: filename=tone-0.1.0-py3-none-any.whl size=666199 sha256=e562ade1583ea3b5b154560b629f851c51af01784becfd1ebb1ba7f7fab09d36
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tnduvz9h/wheels/29/47/43/937a3f873d10b8042bb3a7430568f16d270f6bb8867f7efb91
# Successfully built tone
# Installing collected packages: tone
#   Attempting uninstall: tone
#     Found existing installation: tone 0.1.0
#     Uninstalling tone-0.1.0:
#       Successfully uninstalled tone-0.1.0
# Successfully installed tone-0.1.0
# Creating virtualenv tone-WDJ9Z9fk-py3.12 in /root/.cache/pypoetry/virtualenvs
# Installing dependencies from lock file
#
# Package operations: 122 installs, 0 updates, 0 removals
#
#   - Installing frozenlist (1.7.0): Pending...
#   - Installing idna (3.10): Pending...
#   - Installing multidict (6.6.3): Pending...
#   - Installing propcache (0.3.2): Pending...
#   - Installing typing-extensions (4.14.0): Pending...
#   - Installing idna (3.10): Pending...
#   - Installing multidict (6.6.3): Pending...
#   - Installing propcache (0.3.2): Pending...
#   - Installing typing-extensions (4.14.0): Pending...
#   - Installing frozenlist (1.7.0): Installing...
#   - Installing idna (3.10): Pending...
#   - Installing multidict (6.6.3): Pending...
#   - Installing propcache (0.3.2): Pending...
#   - Installing typing-extensions (4.14.0): Pending...
#   - Installing typing-extensions (4.14.0): Installing...
#   - Installing idna (3.10): Pending...
#   - Installing multidict (6.6.3): Pending...
#   - Installing propcache (0.3.2): Pending...
#   - Installing typing-extensions (4.14.0): Installing...
#   - Installing frozenlist (1.7.0)
#   - Installing idna (3.10): Pending...
#   - Installing multidict (6.6.3): Pending...
#   - Installing propcache (0.3.2): Pending...
#   - Installing typing-extensions (4.14.0): Installing...
#   - Installing typing-extensions (4.14.0)
#   - Installing propcache (0.3.2): Pending...
#   - Installing typing-extensions (4.14.0)
#   - Installing multidict (6.6.3): Installing...
#   - Installing propcache (0.3.2): Pending...
#   - Installing typing-extensions (4.14.0)
#   - Installing typing-extensions (4.14.0)
#   - Installing propcache (0.3.2): Installing...
#   - Installing typing-extensions (4.14.0)
#   - Installing multidict (6.6.3): Installing...
#   - Installing propcache (0.3.2): Installing...
#   - Installing typing-extensions (4.14.0)
#   - Installing idna (3.10): Installing...
#   - Installing multidict (6.6.3): Installing...
#   - Installing propcache (0.3.2): Installing...
#   - Installing typing-extensions (4.14.0)
#   - Installing propcache (0.3.2): Installing...
#   - Installing typing-extensions (4.14.0)
#   - Installing multidict (6.6.3)
#   - Installing propcache (0.3.2): Installing...
#   - Installing typing-extensions (4.14.0)
#   - Installing typing-extensions (4.14.0)
#   - Installing propcache (0.3.2)
#   - Installing typing-extensions (4.14.0)
#   - Installing multidict (6.6.3)
#   - Installing propcache (0.3.2)
#   - Installing typing-extensions (4.14.0)
#   - Installing idna (3.10)
#   - Installing multidict (6.6.3)
#   - Installing propcache (0.3.2)
#   - Installing typing-extensions (4.14.0)
#   - Installing aiohappyeyeballs (2.6.1): Pending...
#   - Installing aiosignal (1.4.0): Pending...
#   - Installing certifi (2025.6.15): Pending...
#   - Installing attrs (25.3.0): Pending...
#   - Installing charset-normalizer (3.4.2): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing aiosignal (1.4.0): Pending...
#   - Installing certifi (2025.6.15): Pending...
#   - Installing attrs (25.3.0): Pending...
#   - Installing charset-normalizer (3.4.2): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing aiohappyeyeballs (2.6.1): Installing...
#   - Installing aiosignal (1.4.0): Pending...
#   - Installing certifi (2025.6.15): Pending...
#   - Installing attrs (25.3.0): Pending...
#   - Installing charset-normalizer (3.4.2): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing charset-normalizer (3.4.2): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing aiosignal (1.4.0): Pending...
#   - Installing certifi (2025.6.15): Pending...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing aiohappyeyeballs (2.6.1)
#   - Installing aiosignal (1.4.0): Pending...
#   - Installing certifi (2025.6.15): Pending...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Pending...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Pending...
#   - Installing certifi (2025.6.15): Pending...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Pending...
#   - Installing aiosignal (1.4.0): Installing...
#   - Installing certifi (2025.6.15): Pending...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Pending...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Pending...
#   - Installing certifi (2025.6.15): Installing...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Pending...
#   - Installing six (1.17.0): Installing...
#   - Installing certifi (2025.6.15): Installing...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Installing...
#   - Installing aiosignal (1.4.0)
#   - Installing certifi (2025.6.15): Installing...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Installing...
#   - Installing urllib3 (2.4.0): Pending...
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Installing...
#   - Installing urllib3 (2.4.0): Pending...
#   - Installing certifi (2025.6.15)
#   - Installing attrs (25.3.0): Installing...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0): Installing...
#   - Installing urllib3 (2.4.0): Pending...
#   - Installing yarl (1.20.1): Pending...
#   - Installing urllib3 (2.4.0): Pending...
#   - Installing yarl (1.20.1): Pending...
#   - Installing six (1.17.0)
#   - Installing urllib3 (2.4.0): Pending...
#   - Installing yarl (1.20.1): Pending...
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0)
#   - Installing urllib3 (2.4.0): Pending...
#   - Installing yarl (1.20.1): Pending...
#   - Installing attrs (25.3.0)
#   - Installing charset-normalizer (3.4.2): Installing...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0)
#   - Installing urllib3 (2.4.0): Pending...
#   - Installing yarl (1.20.1): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0)
#   - Installing urllib3 (2.4.0): Pending...
#   - Installing yarl (1.20.1): Pending...
#   - Installing charset-normalizer (3.4.2)
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Pending...
#   - Installing six (1.17.0)
#   - Installing urllib3 (2.4.0): Pending...
#   - Installing yarl (1.20.1): Pending...
#   - Installing yarl (1.20.1): Pending...
#   - Installing urllib3 (2.4.0): Installing...
#   - Installing yarl (1.20.1): Pending...
#   - Installing yarl (1.20.1): Installing...
#   - Installing yarl (1.20.1)
#   - Installing yarl (1.20.1)
#   - Installing urllib3 (2.4.0)
#   - Installing yarl (1.20.1)
#   - Installing six (1.17.0)
#   - Installing urllib3 (2.4.0)
#   - Installing yarl (1.20.1)
#   - Installing nvidia-nvjitlink-cu12 (12.6.85): Installing...
#   - Installing six (1.17.0)
#   - Installing urllib3 (2.4.0)
#   - Installing yarl (1.20.1)
#   - Installing six (1.17.0)
#   - Installing urllib3 (2.4.0)
#   - Installing yarl (1.20.1)
#   - Installing nvidia-nvjitlink-cu12 (12.6.85)
#   - Installing six (1.17.0)
#   - Installing urllib3 (2.4.0)
#   - Installing yarl (1.20.1)
#   - Installing aiohttp (3.12.14): Pending...
#   - Installing asttokens (3.0.0): Pending...
#   - Installing dill (0.3.7): Pending...
#   - Installing executing (2.2.0): Pending...
#   - Installing filelock (3.18.0): Pending...
#   - Installing fsspec (2025.5.1): Pending...
#   - Installing dill (0.3.7): Pending...
#   - Installing executing (2.2.0): Pending...
#   - Installing filelock (3.18.0): Pending...
#   - Installing fsspec (2025.5.1): Pending...
#   - Installing asttokens (3.0.0): Installing...
#   - Installing dill (0.3.7): Pending...
#   - Installing executing (2.2.0): Pending...
#   - Installing filelock (3.18.0): Pending...
#   - Installing fsspec (2025.5.1): Pending...
#   - Installing fsspec (2025.5.1): Pending...
#   - Installing filelock (3.18.0): Installing...
#   - Installing fsspec (2025.5.1): Pending...
#   - Installing executing (2.2.0): Pending...
#   - Installing filelock (3.18.0): Installing...
#   - Installing fsspec (2025.5.1): Pending...
#   - Installing dill (0.3.7): Installing...
#   - Installing executing (2.2.0): Pending...
#   - Installing filelock (3.18.0): Installing...
#   - Installing fsspec (2025.5.1): Pending...
#   - Installing filelock (3.18.0): Installing...
#   - Installing fsspec (2025.5.1): Pending...
#   - Installing executing (2.2.0): Installing...
#   - Installing filelock (3.18.0): Installing...
#   - Installing fsspec (2025.5.1): Pending...
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing dill (0.3.7): Installing...
#   - Installing executing (2.2.0): Installing...
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing asttokens (3.0.0)
#   - Installing dill (0.3.7): Installing...
#   - Installing executing (2.2.0): Installing...
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing markupsafe (3.0.2): Pending...
#   - Installing asttokens (3.0.0)
#   - Installing dill (0.3.7): Installing...
#   - Installing executing (2.2.0): Installing...
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing markupsafe (3.0.2): Pending...
#   - Installing aiohttp (3.12.14): Installing...
#   - Installing asttokens (3.0.0)
#   - Installing dill (0.3.7): Installing...
#   - Installing executing (2.2.0): Installing...
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing markupsafe (3.0.2): Pending...
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing markupsafe (3.0.2): Pending...
#   - Installing executing (2.2.0)
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing markupsafe (3.0.2): Pending...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing markupsafe (3.0.2): Installing...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing executing (2.2.0)
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing markupsafe (3.0.2): Installing...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing dill (0.3.7)
#   - Installing executing (2.2.0)
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1): Installing...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing markupsafe (3.0.2): Installing...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing mpmath (1.3.0): Pending...
#   - Installing markupsafe (3.0.2)
#   - Installing mpmath (1.3.0): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing mpmath (1.3.0): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing markupsafe (3.0.2)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing fsspec (2025.5.1)
#   - Installing hf-xet (1.1.4): Pending...
#   - Installing markupsafe (3.0.2)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing markupsafe (3.0.2)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing hf-xet (1.1.4): Installing...
#   - Installing markupsafe (3.0.2)
#   - Installing mpmath (1.3.0): Installing...
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing mpmath (1.3.0)
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing packaging (25.0): Pending...
#   - Installing asttokens (3.0.0)
#   - Installing dill (0.3.7)
#   - Installing executing (2.2.0)
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1)
#   - Installing hf-xet (1.1.4): Installing...
#   - Installing markupsafe (3.0.2)
#   - Installing mpmath (1.3.0)
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing packaging (25.0): Pending...
#   - Installing aiohttp (3.12.14)
#   - Installing asttokens (3.0.0)
#   - Installing dill (0.3.7)
#   - Installing executing (2.2.0)
#   - Installing filelock (3.18.0)
#   - Installing fsspec (2025.5.1)
#   - Installing hf-xet (1.1.4): Installing...
#   - Installing markupsafe (3.0.2)
#   - Installing mpmath (1.3.0)
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing packaging (25.0): Pending...
#   - Installing parso (0.8.4): Pending...
#   - Installing markupsafe (3.0.2)
#   - Installing mpmath (1.3.0)
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing packaging (25.0): Pending...
#   - Installing parso (0.8.4): Pending...
#   - Installing hf-xet (1.1.4)
#   - Installing markupsafe (3.0.2)
#   - Installing mpmath (1.3.0)
#   - Installing numpy (1.26.4): Pending...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing packaging (25.0): Pending...
#   - Installing parso (0.8.4): Pending...
#   - Installing platformdirs (4.3.8): Pending...
#   - Installing parso (0.8.4): Pending...
#   - Installing platformdirs (4.3.8): Pending...
#   - Installing packaging (25.0): Installing...
#   - Installing parso (0.8.4): Pending...
#   - Installing platformdirs (4.3.8): Pending...
#   - Installing platformdirs (4.3.8): Installing...
#   - Installing platformdirs (4.3.8): Installing...
#   - Installing parso (0.8.4): Installing...
#   - Installing platformdirs (4.3.8): Installing...
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0): Pending...
#   - Installing parso (0.8.4): Installing...
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0): Pending...
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4): Installing...
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0): Pending...
#   - Installing pure-eval (0.2.3): Pending...
#   - Installing pure-eval (0.2.3): Pending...
#   - Installing ptyprocess (0.7.0): Installing...
#   - Installing pure-eval (0.2.3): Pending...
#   - Installing pure-eval (0.2.3): Pending...
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3): Pending...
#   - Installing pycparser (2.22): Pending...
#   - Installing pycparser (2.22): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing pycparser (2.22): Pending...
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing pycparser (2.22): Pending...
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing pycparser (2.22): Pending...
#   - Installing pygments (2.19.2): Pending...
#   - Installing pycparser (2.22): Pending...
#   - Installing pygments (2.19.2): Pending...
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22): Pending...
#   - Installing pygments (2.19.2): Pending...
#   - Installing python-dateutil (2.9.0.post0): Pending...
#   - Installing pygments (2.19.2): Pending...
#   - Installing python-dateutil (2.9.0.post0): Pending...
#   - Installing pycparser (2.22): Installing...
#   - Installing pygments (2.19.2): Pending...
#   - Installing python-dateutil (2.9.0.post0): Pending...
#   - Installing python-dateutil (2.9.0.post0): Pending...
#   - Installing pygments (2.19.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Pending...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22): Installing...
#   - Installing pygments (2.19.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing numpy (1.26.4): Installing...
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22): Installing...
#   - Installing pygments (2.19.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing pygments (2.19.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2): Installing...
#   - Installing python-dateutil (2.9.0.post0): Installing...
#   - Installing pytz (2025.2): Pending...
#   - Installing pytz (2025.2): Installing...
#   - Installing pytz (2025.2): Installing...
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2): Installing...
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing pyyaml (6.0.2): Installing...
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4): Pending...
#   - Installing requests (2.32.4): Installing...
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0): Pending...
#   - Installing setuptools (80.9.0): Installing...
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2): Installing...
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0): Installing...
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2): Installing...
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0): Installing...
#   - Installing tqdm (4.67.1): Pending...
#   - Installing tqdm (4.67.1): Installing...
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3): Pending...
#   - Installing traitlets (5.14.3): Installing...
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2): Pending...
#   - Installing tzdata (2025.2): Installing...
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0): Installing...
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2): Installing...
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0): Installing...
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2): Installing...
#   - Installing wcwidth (0.2.13): Pending...
#   - Installing wcwidth (0.2.13): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2): Installing...
#   - Installing wcwidth (0.2.13)
#   - Installing wcwidth (0.2.13)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
#   - Installing numpy (1.26.4)
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Pending...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Pending...
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Installing...
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
# Installing /root/.cache/pypoetry/virtualenvs/tone-WDJ9Z9fk-py3.12/lib/python3.12/site-packages/nvidia/__init__.py over existing file
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Installing...
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
#   - Installing nvidia-cublas-cu12 (12.6.4.1): Installing...
#   - Installing nvidia-cusparse-cu12 (12.5.4.2): Installing...
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
# Installing /root/.cache/pypoetry/virtualenvs/tone-WDJ9Z9fk-py3.12/lib/python3.12/site-packages/nvidia/__init__.py over existing file
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
#   - Installing nvidia-cusparse-cu12 (12.5.4.2)
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
#   - Installing nvidia-cusparse-cu12 (12.5.4.2)
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
#   - Installing nvidia-cublas-cu12 (12.6.4.1)
#   - Installing nvidia-cusparse-cu12 (12.5.4.2)
#   - Installing packaging (25.0)
#   - Installing parso (0.8.4)
#   - Installing platformdirs (4.3.8)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.3)
#   - Installing pycparser (2.22)
#   - Installing pygments (2.19.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2025.2)
#   - Installing pyyaml (6.0.2)
#   - Installing requests (2.32.4)
#   - Installing setuptools (80.9.0)
#   - Installing tqdm (4.67.1)
#   - Installing traitlets (5.14.3)
#   - Installing tzdata (2025.2)
#   - Installing wcwidth (0.2.13)
#   - Installing cffi (1.17.1): Pending...
#   - Installing decorator (5.2.1): Pending...
#   - Installing huggingface-hub (0.33.0): Pending...
#   - Installing humanfriendly (10.0): Pending...
#   - Installing ipython-pygments-lexers (1.1.1): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing ipython-pygments-lexers (1.1.1): Installing...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing huggingface-hub (0.33.0): Pending...
#   - Installing humanfriendly (10.0): Pending...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing decorator (5.2.1): Installing...
#   - Installing huggingface-hub (0.33.0): Pending...
#   - Installing humanfriendly (10.0): Pending...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing humanfriendly (10.0): Installing...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing huggingface-hub (0.33.0): Pending...
#   - Installing humanfriendly (10.0): Installing...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing decorator (5.2.1)
#   - Installing huggingface-hub (0.33.0): Pending...
#   - Installing humanfriendly (10.0): Installing...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing decorator (5.2.1)
#   - Installing huggingface-hub (0.33.0): Pending...
#   - Installing humanfriendly (10.0): Installing...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing cffi (1.17.1): Installing...
#   - Installing decorator (5.2.1)
#   - Installing huggingface-hub (0.33.0): Pending...
#   - Installing humanfriendly (10.0): Installing...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing humanfriendly (10.0): Installing...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing huggingface-hub (0.33.0): Installing...
#   - Installing humanfriendly (10.0): Installing...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing humanfriendly (10.0)
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing jupyter-core (5.8.1): Pending...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing jupyter-core (5.8.1): Pending...
#   - Installing jedi (0.19.2): Installing...
#   - Installing jinja2 (3.1.6): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing jupyter-core (5.8.1): Pending...
#   - Installing joblib (1.5.1): Pending...
#   - Installing jupyter-core (5.8.1): Pending...
#   - Installing jinja2 (3.1.6): Installing...
#   - Installing joblib (1.5.1): Pending...
#   - Installing jupyter-core (5.8.1): Pending...
#   - Installing jupyter-core (5.8.1): Installing...
#   - Installing jupyter-core (5.8.1): Installing...
#   - Installing joblib (1.5.1): Installing...
#   - Installing jupyter-core (5.8.1): Installing...
#   - Installing jupyter-core (5.8.1)
#   - Installing llvmlite (0.44.0): Pending...
#   - Installing joblib (1.5.1): Installing...
#   - Installing jupyter-core (5.8.1)
#   - Installing llvmlite (0.44.0): Pending...
#   - Installing jinja2 (3.1.6)
#   - Installing joblib (1.5.1): Installing...
#   - Installing jupyter-core (5.8.1)
#   - Installing llvmlite (0.44.0): Pending...
#   - Installing matplotlib-inline (0.1.7): Pending...
#   - Installing decorator (5.2.1)
#   - Installing huggingface-hub (0.33.0): Installing...
#   - Installing humanfriendly (10.0)
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Installing...
#   - Installing jinja2 (3.1.6)
#   - Installing joblib (1.5.1): Installing...
#   - Installing jupyter-core (5.8.1)
#   - Installing llvmlite (0.44.0): Pending...
#   - Installing matplotlib-inline (0.1.7): Pending...
#   - Installing cffi (1.17.1)
#   - Installing decorator (5.2.1)
#   - Installing huggingface-hub (0.33.0): Installing...
#   - Installing humanfriendly (10.0)
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Installing...
#   - Installing jinja2 (3.1.6)
#   - Installing joblib (1.5.1): Installing...
#   - Installing jupyter-core (5.8.1)
#   - Installing llvmlite (0.44.0): Pending...
#   - Installing matplotlib-inline (0.1.7): Pending...
#   - Installing multiprocess (0.70.15): Pending...
#   - Installing multiprocess (0.70.15): Pending...
#   - Installing matplotlib-inline (0.1.7): Installing...
#   - Installing multiprocess (0.70.15): Pending...
#   - Installing multiprocess (0.70.15): Pending...
#   - Installing matplotlib-inline (0.1.7)
#   - Installing multiprocess (0.70.15): Pending...
#   - Installing networkx (3.5): Pending...
#   - Installing networkx (3.5): Pending...
#   - Installing multiprocess (0.70.15): Installing...
#   - Installing networkx (3.5): Pending...
#   - Installing networkx (3.5): Installing...
#   - Installing networkx (3.5): Installing...
#   - Installing multiprocess (0.70.15)
#   - Installing networkx (3.5): Installing...
#   - Installing nvidia-cuda-cupti-cu12 (12.6.80): Pending...
#   - Installing humanfriendly (10.0)
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Installing...
#   - Installing jinja2 (3.1.6)
#   - Installing joblib (1.5.1): Installing...
#   - Installing jupyter-core (5.8.1)
#   - Installing llvmlite (0.44.0): Pending...
#   - Installing matplotlib-inline (0.1.7)
#   - Installing multiprocess (0.70.15)
#   - Installing networkx (3.5): Installing...
#   - Installing nvidia-cuda-cupti-cu12 (12.6.80): Pending...
#   - Installing huggingface-hub (0.33.0)
#   - Installing humanfriendly (10.0)
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Installing...
#   - Installing jinja2 (3.1.6)
#   - Installing joblib (1.5.1): Installing...
#   - Installing jupyter-core (5.8.1)
#   - Installing llvmlite (0.44.0): Pending...
#   - Installing matplotlib-inline (0.1.7)
#   - Installing multiprocess (0.70.15)
#   - Installing networkx (3.5): Installing...
#   - Installing nvidia-cuda-cupti-cu12 (12.6.80): Pending...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.6.77): Pending...
#   - Installing jupyter-core (5.8.1)
#   - Installing llvmlite (0.44.0): Pending...
#   - Installing matplotlib-inline (0.1.7)
#   - Installing multiprocess (0.70.15)
#   - Installing networkx (3.5): Installing...
#   - Installing nvidia-cuda-cupti-cu12 (12.6.80): Pending...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.6.77): Pending...
#   - Installing joblib (1.5.1)
#   - Installing jupyter-core (5.8.1)
#   - Installing llvmlite (0.44.0): Pending...
#   - Installing matplotlib-inline (0.1.7)
#   - Installing multiprocess (0.70.15)
#   - Installing networkx (3.5): Installing...
#   - Installing nvidia-cuda-cupti-cu12 (12.6.80): Pending...
#   - Installing nvidia-cuda-nvrtc-cu12 (12.6.77): Pending...
#   - Installing nvidia-cuda-runtime-cu12 (12.6.77): Pending...
#   - Installing nvidia-cuda-runtime-cu12 (12.6.77): Installing...
# ...
#   - Installing nvidia-cusparselt-cu12 (0.6.3): Installing...
#   - Installing llvmlite (0.44.0)
#   - Installing matplotlib-inline (0.1.7)
#   - Installing multiprocess (0.70.15)
#   - Installing networkx (3.5)
#   - Installing nvidia-cuda-cupti-cu12 (12.6.80)
#   - Installing nvidia-cuda-nvrtc-cu12 (12.6.77)
#   - Installing nvidia-cuda-runtime-cu12 (12.6.77)
#   - Installing nvidia-cudnn-cu12 (9.5.1.17): Installing...
#   - Installing nvidia-cufft-cu12 (11.3.0.4): Installing...
#   - Installing nvidia-cufile-cu12 (1.11.1.6)
#   - Installing nvidia-curand-cu12 (10.3.7.77): Installing...
#   - Installing nvidia-cusolver-cu12 (11.7.1.2): Installing...
#   - Installing nvidia-cusparselt-cu12 (0.6.3): Installing...
#   - Installing nvidia-nccl-cu12 (2.26.2): Pending...
#   - Installing nvidia-cusolver-cu12 (11.7.1.2): Installing...
#   - Installing nvidia-cusparselt-cu12 (0.6.3): Installing...
#   - Installing nvidia-nccl-cu12 (2.26.2): Pending...
#   - Installing nvidia-curand-cu12 (10.3.7.77)
#   - Installing nvidia-cusolver-cu12 (11.7.1.2): Installing...
#   - Installing nvidia-cusparselt-cu12 (0.6.3): Installing...
#   - Installing nvidia-nccl-cu12 (2.26.2): Pending...
#   - Installing nvidia-nvtx-cu12 (12.6.77): Pending...
#   - Installing nvidia-nvtx-cu12 (12.6.77): Pending...
#   - Installing nvidia-nccl-cu12 (2.26.2): Installing...
#   - Installing nvidia-nvtx-cu12 (12.6.77): Pending...
# Installing /root/.cache/pypoetry/virtualenvs/tone-WDJ9Z9fk-py3.12/lib/python3.12/site-packages/nvidia/__init__.py over existing file
#   - Installing nvidia-nvtx-cu12 (12.6.77): Installing...
# Installing /root/.cache/pypoetry/virtualenvs/tone-WDJ9Z9fk-py3.12/lib/python3.12/site-packages/nvidia/__init__.py over existing file
#   - Installing nvidia-nvtx-cu12 (12.6.77)
#   - Installing pandas (2.3.1): Pending...
#   - Installing pandas (2.3.1): Installing...
#   - Installing pandas (2.3.1)
#   - Installing pexpect (4.9.0): Pending...
#   - Installing pexpect (4.9.0): Installing...
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.51): Pending...
#   - Installing prompt-toolkit (3.0.51): Installing...
#   - Installing prompt-toolkit (3.0.51)
#   - Installing pyarrow (20.0.0): Pending...
#   - Installing pyarrow (20.0.0): Installing...
#   - Installing pyarrow (20.0.0)
#   - Installing pyzmq (27.0.0): Pending...
#   - Installing pyzmq (27.0.0): Installing...
#   - Installing pyzmq (27.0.0)
#   - Installing scipy (1.16.0): Pending...
#   - Installing scipy (1.16.0): Installing...
#   - Installing nvidia-cusparselt-cu12 (0.6.3): Installing...
#   - Installing nvidia-nccl-cu12 (2.26.2): Installing...
#   - Installing nvidia-nvtx-cu12 (12.6.77)
#   - Installing pandas (2.3.1)
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.51)
#   - Installing pyarrow (20.0.0)
#   - Installing pyzmq (27.0.0)
#   - Installing scipy (1.16.0): Installing...
#   - Installing nvidia-cusolver-cu12 (11.7.1.2)
#   - Installing nvidia-cusparselt-cu12 (0.6.3): Installing...
#   - Installing nvidia-nccl-cu12 (2.26.2): Installing...
#   - Installing nvidia-nvtx-cu12 (12.6.77)
#   - Installing pandas (2.3.1)
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.51)
#   - Installing pyarrow (20.0.0)
#   - Installing pyzmq (27.0.0)
#   - Installing scipy (1.16.0): Installing...
#   - Installing sortedcontainers (2.4.0): Pending...
#   - Installing sortedcontainers (2.4.0): Installing...
#   - Installing sortedcontainers (2.4.0)
#   - Installing stack-data (0.6.3): Pending...
#   - Installing stack-data (0.6.3): Installing...
#   - Installing stack-data (0.6.3)
#   - Installing sympy (1.14.0): Pending...
#   - Installing sympy (1.14.0): Installing...
#   - Installing nvidia-nccl-cu12 (2.26.2): Installing...
#   - Installing nvidia-nvtx-cu12 (12.6.77)
#   - Installing pandas (2.3.1)
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.51)
#   - Installing pyarrow (20.0.0)
#   - Installing pyzmq (27.0.0)
#   - Installing scipy (1.16.0): Installing...
#   - Installing sortedcontainers (2.4.0)
#   - Installing stack-data (0.6.3)
#   - Installing sympy (1.14.0): Installing...
#   - Installing nvidia-cusparselt-cu12 (0.6.3)
#   - Installing nvidia-nccl-cu12 (2.26.2): Installing...
#   - Installing nvidia-nvtx-cu12 (12.6.77)
#   - Installing pandas (2.3.1)
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.51)
#   - Installing pyarrow (20.0.0)
#   - Installing pyzmq (27.0.0)
#   - Installing scipy (1.16.0): Installing...
#   - Installing sortedcontainers (2.4.0)
#   - Installing stack-data (0.6.3)
#   - Installing sympy (1.14.0): Installing...
#   - Installing threadpoolctl (3.6.0): Pending...
#   - Installing threadpoolctl (3.6.0): Installing...
#   - Installing threadpoolctl (3.6.0)
#   - Installing tornado (6.5.1): Pending...
#   - Installing nvidia-cufile-cu12 (1.11.1.6)
#   - Installing nvidia-curand-cu12 (10.3.7.77)
#   - Installing nvidia-cusolver-cu12 (11.7.1.2)
#   - Installing nvidia-cusparselt-cu12 (0.6.3)
#   - Installing nvidia-nccl-cu12 (2.26.2): Installing...
#   - Installing nvidia-nvtx-cu12 (12.6.77)
#   - Installing pandas (2.3.1)
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.51)
#   - Installing pyarrow (20.0.0)
#   - Installing pyzmq (27.0.0)
#   - Installing scipy (1.16.0): Installing...
#   - Installing sortedcontainers (2.4.0)
#   - Installing stack-data (0.6.3)
#   - Installing sympy (1.14.0): Installing...
#   - Installing threadpoolctl (3.6.0)
#   - Installing tornado (6.5.1): Pending...
#   - Installing nvidia-cufft-cu12 (11.3.0.4)
#   - Installing nvidia-cufile-cu12 (1.11.1.6)
#   - Installing nvidia-curand-cu12 (10.3.7.77)
#   - Installing nvidia-cusolver-cu12 (11.7.1.2)
#   - Installing nvidia-cusparselt-cu12 (0.6.3)
#   - Installing nvidia-nccl-cu12 (2.26.2): Installing...
#   - Installing nvidia-nvtx-cu12 (12.6.77)
#   - Installing pandas (2.3.1)
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.51)
#   - Installing pyarrow (20.0.0)
#   - Installing pyzmq (27.0.0)
#   - Installing scipy (1.16.0): Installing...
#   - Installing sortedcontainers (2.4.0)
#   - Installing stack-data (0.6.3)
#   - Installing sympy (1.14.0): Installing...
#   - Installing threadpoolctl (3.6.0)
#   - Installing tornado (6.5.1): Pending...
#   - Installing triton (3.3.1): Pending...
#   - Installing triton (3.3.1): Pending...
#   - Installing tornado (6.5.1): Installing...
#   - Installing triton (3.3.1): Pending...
#   - Installing triton (3.3.1): Pending...
#   - Installing tornado (6.5.1)
#   - Installing triton (3.3.1): Pending...
#   - Installing xxhash (3.5.0): Pending...
#   - Installing xxhash (3.5.0): Installing...
#   - Installing xxhash (3.5.0)
#   - Installing xxhash (3.5.0)
#   - Installing triton (3.3.1): Installing...
#   - Installing xxhash (3.5.0)
#   - Installing threadpoolctl (3.6.0)
#   - Installing tornado (6.5.1)
#   - Installing triton (3.3.1): Installing...
#   - Installing xxhash (3.5.0)
#   - Installing sympy (1.14.0)
#   - Installing threadpoolctl (3.6.0)
#   - Installing tornado (6.5.1)
#   - Installing triton (3.3.1): Installing...
#   - Installing xxhash (3.5.0)
#   - Installing nvidia-nvtx-cu12 (12.6.77)
#   - Installing pandas (2.3.1)
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.51)
#   - Installing pyarrow (20.0.0)
#   - Installing pyzmq (27.0.0)
#   - Installing scipy (1.16.0): Installing...
#   - Installing sortedcontainers (2.4.0)
#   - Installing stack-data (0.6.3)
#   - Installing sympy (1.14.0)
#   - Installing threadpoolctl (3.6.0)
#   - Installing tornado (6.5.1)
#   - Installing triton (3.3.1): Installing...
#   - Installing xxhash (3.5.0)
#   - Installing nvidia-nccl-cu12 (2.26.2)
#   - Installing nvidia-nvtx-cu12 (12.6.77)
#   - Installing pandas (2.3.1)
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.51)
#   - Installing pyarrow (20.0.0)
#   - Installing pyzmq (27.0.0)
#   - Installing scipy (1.16.0): Installing...
#   - Installing sortedcontainers (2.4.0)
#   - Installing stack-data (0.6.3)
#   - Installing sympy (1.14.0)
#   - Installing threadpoolctl (3.6.0)
#   - Installing tornado (6.5.1)
#   - Installing triton (3.3.1): Installing...
#   - Installing xxhash (3.5.0)
#   - Installing sortedcontainers (2.4.0)
#   - Installing stack-data (0.6.3)
#   - Installing sympy (1.14.0)
#   - Installing threadpoolctl (3.6.0)
#   - Installing tornado (6.5.1)
#   - Installing triton (3.3.1): Installing...
#   - Installing xxhash (3.5.0)
#   - Installing scipy (1.16.0)
#   - Installing sortedcontainers (2.4.0)
#   - Installing stack-data (0.6.3)
#   - Installing sympy (1.14.0)
#   - Installing threadpoolctl (3.6.0)
#   - Installing tornado (6.5.1)
#   - Installing triton (3.3.1): Installing...
#   - Installing xxhash (3.5.0)
# ^C
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 324, in run
#     session = self.get_default_session(options)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/index_command.py", line 71, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/index_command.py", line 100, in _build_session
#     session = PipSession(
#               ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/network/session.py", line 344, in __init__
#     self.headers["User-Agent"] = user_agent()
#                                  ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/network/session.py", line 177, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 189, in get_distribution
#     return next(matches, None)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 186, in <genexpr>
#     for distribution in self.iter_all_distributions()
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/base.py", line 612, in iter_all_distributions
#     for dist in self._iter_distributions():
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 177, in _iter_distributions
#     for dist in finder.find_eggs(location):
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 144, in find_eggs
#     yield from self._find_eggs_in_dir(location)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 111, in _find_eggs_in_dir
#     from pip._vendor.pkg_resources import find_distributions
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3291, in <module>
#     @_call_aside
#      ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3266, in _call_aside
#     f(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3324, in _initialize_master_working_set
#     list(map(working_set.add_entry, sys.path))
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 640, in add_entry
#     for dist in find_distributions(entry, True):
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2102, in find_on_path
#     yield from factory(fullpath)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2166, in distributions_from_metadata
#     yield Distribution.from_location(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2629, in from_location
#     return cls(
#            ^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 216, in exc_logging_wrapper
#     logger.debug("Exception information:", exc_info=True)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1527, in debug
#     self._log(DEBUG, msg, args, **kwargs)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1684, in _log
#     self.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1028, in handle
#     self.emit(record)
#   File "/usr/lib/python3.12/logging/handlers.py", line 75, in emit
#     logging.FileHandler.emit(self, record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1280, in emit
#     StreamHandler.emit(self, record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/utils/logging.py", line 112, in format
#     formatted = super().format(record)
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 711, in format
#     record.exc_text = self.formatException(record.exc_info)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 661, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "/usr/lib/python3.12/traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 418, in _extract_from_extended_frame_gen
#     for f, (lineno, end_lineno, colno, end_colno) in frame_gen:
#                                                      ^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 355, in _walk_tb_with_full_positions
#     positions = _get_code_position(tb.tb_frame.f_code, tb.tb_lasti)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 369, in _get_code_position
#     return next(itertools.islice(positions_gen, instruction_index // 2, None))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C
# Requirement already satisfied: torchcodec in /usr/local/lib/python3.12/dist-packages (0.9.1)
# Requirement already satisfied: protobuf==5.29.3 in /usr/local/lib/python3.12/dist-packages (5.29.3)

# %%
import torch


torch.backends.cuda.matmul.allow_tf32 = False
torch.backends.cudnn.allow_tf32 = False

# %%
# Sample rate used in the base model
SAMPLE_RATE = 8000

# Padding added to each audio during training to improve performance
LEFT_PAD_MS = 300
RIGHT_PAD_MS = 300
LEFT_PAD_SIZE = round(SAMPLE_RATE * LEFT_PAD_MS * 1e-3)
RIGHT_PAD_SIZE = round(SAMPLE_RATE * RIGHT_PAD_MS * 1e-3)

# %% [markdown]
# ## Prepare Data, Tokenizer, Feature Extractor
#
# ### Load data either using Huggingface datasets or locally
#
# If you want to use your own data, create a metadata manifest JSON-lines file with the following columns: ```audio, text```

# %%
from datasets import Audio, load_dataset


def load_from_local(
    train_path,
    validation_path,
    sample_rate=SAMPLE_RATE,
    audio_column="audio",
    text_column="text",
    ):
    """
    Load audios from a JSON-lines manifest containing the following features in each row: audio and text.
    """
    manifest_dict = {"train": train_path, "validation": validation_path}
    dataset = load_dataset("json", data_files=manifest_dict)
    if text_column != "text":
        dataset = dataset.rename_column(text_column, "text")
    if audio_column != "audio":
        dataset = dataset.rename_column(audio_column, "audio")
    dataset = dataset.cast_column(audio_column, Audio(sampling_rate=sample_rate))
    return dataset


def load_from_huggingface(
        dataset_name,
        sample_rate=SAMPLE_RATE,
        audio_column="audio",
        text_column="text",
        **kwargs
    ):
    """
    Load an ASR dataset from huggingface.
    You might need to change this function if you use a custom dataset.
    """
    dataset = load_dataset(dataset_name, **kwargs)
    dataset = dataset.select_columns([audio_column, text_column])
    if text_column != "text":
        dataset = dataset.rename_column(text_column, "text")
    if audio_column != "audio":
        dataset = dataset.rename_column(audio_column, "audio")
    dataset = dataset.cast_column(audio_column, Audio(sampling_rate=sample_rate))
    return dataset

# %% [markdown]
# ### Dataset
#
# In this example we will fine-tune on the dataset https://huggingface.co/datasets/Vikhrmodels/ToneBooks by Vikhrmodels. It contains recordings of books with labelled tone and timbre, but we will use only audio and transcriptions.
#
# You can use your own dataset with `load_from_local` function.

# %%
# This will save the dataset to the cache folder
asr_dataset = load_from_huggingface(
    dataset_name="Vikhrmodels/ToneBooks",
    audio_column="audio",
    text_column="text",
)
# Out:
# Loading dataset shards:   0%|          | 0/21 [00:00<?, ?it/s]

# %%
# Run this if you don't want to use cache for all processing steps
from datasets import disable_caching


# disable_caching()

# %% [markdown]
# ### Preprocess Data

# %% [markdown]
# Now we should process the data with the model's feature extractor. We will use the Wav2Vec2 tokenizer and feature extractor as they are close to what we need.
#
# The feature extractor is used to add padding and normalize the audio.

# %%
from transformers import Wav2Vec2CTCTokenizer


tokenizer = Wav2Vec2CTCTokenizer.from_pretrained(
    "t-tech/T-one", pad_token="[PAD]", word_delimiter_token="|"
)

# %% [markdown]
# The next step is to wrap Wav2Vec2FeatureExtractor into a Wav2Vec2Processor together with the tokenizer.

# %%
from transformers import Wav2Vec2FeatureExtractor
from transformers import Wav2Vec2Processor


feature_extractor = Wav2Vec2FeatureExtractor(
    feature_size=1,
    sampling_rate=SAMPLE_RATE,
    padding_value=0.0,
    return_attention_mask=False,
    do_normalize=False,
)
processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %% [markdown]
# ### Preprocess the data
#
# Now we have to prepare all training examples. We will normalize the text - convert to lowercase and remove all symbols that are not in the vocabulary.

# %%
import os
import re
import numpy as np


# How many processors to use for data processing
NUM_PROC = os.cpu_count()
REG = re.compile("[а-яё]+")


def prepare_dataset(batch):
    audio = batch["audio"]
    audio_array = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]

    # Add magic padding on both sides to improve model performance
    batch["input_values"] = np.pad(audio_array, (LEFT_PAD_SIZE, RIGHT_PAD_SIZE), mode="constant")
    batch["input_lengths"] = len(batch["input_values"])

    text = " ".join(REG.findall(batch["text"].lower()))
    batch["labels"] = processor(text=text).input_ids
    return batch


asr_dataset = asr_dataset.map(prepare_dataset, remove_columns=["audio", "text"], num_proc=NUM_PROC)
max_input_length_in_sec = 20.0
asr_dataset["train"] = asr_dataset["train"].filter(
    lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate, input_columns=["input_lengths"]
)

# %% [markdown]
# Long input sequences require a lot of memory. Since `T-one` is based on `self-attention` the memory requirement scales quadratically with the input length for long input sequences. For this demo, we will filter all sequences that are longer than 20 seconds out of the training dataset.

# %% [markdown]
# ## Training
#
# The data is processed so that we are ready to start setting up the training pipeline. We will make use of 🤗's [Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer) for which we need:

# %% [markdown]
# #### A Data Collator
#
#
# This data collator must pad both audio and text to the maximum length in the batch separately. The padding tokens in the labels with `-100` so that those tokens are **not** taken into account when computing the loss.

# %%
from tone.training.data_collator import DataCollatorCTCWithPadding


data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# #### Load a pretrained checkpoint
#
# We need to load a pretrained `T-one` checkpoint and configure it correctly for training.
#
# The tokenizer's `pad_token_id` must match with the model's `pad_token_id` or CTC's *blank token* in case of a CTC speech model.

# %%
from tone.training.model_wrapper import ToneForCTC


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ToneForCTC.from_pretrained("t-tech/T-one").to(device)

# %% [markdown]
# #### Evaluation metric
# During training, the model should be evaluated using the Word Error Rate (WER). We define a `compute_metrics` function accordingly.

# %%
import evaluate


wer_metric = evaluate.load("wer")


def compute_metrics(preds):
    pred_logits = preds.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    # Pred ids get padded by -100
    pred_ids[(pred_logits == -100).all(axis=-1)] = processor.tokenizer.pad_token_id
    preds.label_ids[preds.label_ids == -100] = processor.tokenizer.pad_token_id

    # Group repeating tokens to get the final transcription
    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(preds.label_ids, group_tokens=False)
    wer = wer_metric.compute(predictions=pred_str, references=label_str)
    return {"wer": wer}

# %% [markdown]
# #### Define the training configuration.
#
# Set up training parameters to optimize fine-tuning performance.

# %%
from transformers import TrainingArguments


training_args = TrainingArguments(
    output_dir = "tone_ctc",
    per_device_train_batch_size = 8,
    per_device_eval_batch_size = 8,
    dataloader_num_workers = 2,
    eval_on_start = True,
    num_train_epochs = 10,
    bf16 = False,
    fp16 = True,
    gradient_accumulation_steps = 4,
    lr_scheduler_type = "linear",
    eval_strategy = "epoch",
    save_strategy = "epoch",
    logging_strategy = "epoch",
    learning_rate = 5e-5,
    weight_decay = 1e-6,
    warmup_ratio = 0.05,
    save_total_limit = 2,
)

# %% [markdown]
# Now all instances can be passed to Trainer and we are ready to start training!

# %%
from transformers import Trainer


trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=asr_dataset["train"].take(4000),
    eval_dataset=asr_dataset["validation"].take(4000),
    tokenizer=processor.feature_extractor,
)
# Out:
# /tmp/ipython-input-1771692576.py:4: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take a couple of hours depending on the GPU used. During training train and validation loss will be printed along with WER of greedy predictions of the model on the validation set.

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/tone/nn/torch_utils.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   return torch.cuda.amp.autocast(dtype=torch.bfloat16)
#     <div>
#
#       <progress value='None' max='1250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       None
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='18' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 18/500 00:08 < 03:48, 2.11 it/s]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4032920361.py in <cell line: 0>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2323                 hf_hub_utils.enable_progress_bars()
#    2324         else:
# -> 2325             return inner_training_loop(
#    2326                 args=args,
#    2327                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2574
#    2575         if args.eval_on_start:
# -> 2576             self._evaluate(trial, ignore_keys_for_eval, skip_scheduler=True)
#    2577
#    2578         for epoch in range(epochs_trained, num_train_epochs):
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler)
#    3168
#    3169     def _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler=False):
# -> 3170         metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    3171         self._report_to_hp_search(trial, self.state.global_step, metrics)
#    3172
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    4487
#    4488         eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 4489         output = eval_loop(
#    4490             eval_dataloader,
#    4491             description="Evaluation",
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    4673
#    4674         # Main evaluation loop
# -> 4675         for step, inputs in enumerate(dataloader):
#    4676             # Update the observed num examples
#    4677             observed_batch_size = find_batch_size(inputs)
#
# /usr/local/lib/python3.12/dist-packages/accelerate/data_loader.py in __iter__(self)
#     577         """
#     578         Define the `__reduce__` method to ensure a `DataLoaderShard` can be pickled and unpickled. This needs to be
# --> 579         explicitly defined since default pickling behavior is broken by `DataLoaderAdapter` messing with its
#     580         `__class__` member.
#     581         """
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     730                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731                 self._reset()  # type: ignore[call-arg]
# --> 732             data = self._next_data()
#     733             self._num_yielded += 1
#     734             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1480
#    1481             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1482             idx, data = self._get_data()
#    1483             self._tasks_outstanding -= 1
#    1484             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1432         elif self._pin_memory:
#    1433             while self._pin_memory_thread.is_alive():
# -> 1434                 success, data = self._try_get_data()
#    1435                 if success:
#    1436                     return data
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1273         #   (bool: whether successfully get data, any: data if successful else None)
#    1274         try:
# -> 1275             data = self._data_queue.get(timeout=timeout)
#    1276             return (True, data)
#    1277         except Exception as e:
#
# /usr/lib/python3.12/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     357             else:
#     358                 if timeout > 0:
# --> 359                     gotit = waiter.acquire(True, timeout)
#     360                 else:
#     361                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# We have successfuly fine-tuned `T-one` on a new dataset while reducing WER from 9.84 to 6.04. You can do the same with your own dataset.
#
# You can export this checkpoint to onnx using the script `tone/scripts/export.py`.
#
# You can get better results if you use Beam Search decoding with a language model with `StreamingCTCPipeline` initialized with your own checkpoint.

# %% [markdown]
# Export model ONNX

# %%
trainer.save_model("tone_ctc")

# %%
# !pip install onnx
# Out:
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (1.20.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.3)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)

# %%
# !pip install onnxscript
# Out:
# Requirement already satisfied: onnxscript in /usr/local/lib/python3.12/dist-packages (0.5.7)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.5.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnxscript) (1.26.4)
# Requirement already satisfied: onnx_ir<2,>=0.1.12 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.1.14)
# Requirement already satisfied: onnx>=1.16 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (1.20.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (25.0)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (4.15.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.16->onnxscript) (5.29.3)

# %%
# !git clone https://github.com/t-tech/t-one.git
# %cd t-one
# !pip install -e ".[finetune]"
# Out:
# fatal: destination path 't-one' already exists and is not an empty directory.
# /content/t-one/t-one
# Obtaining file:///content/t-one/t-one
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.36.0)
# Requirement already satisfied: kenlm<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.3.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17.3 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (1.26.4)
# Requirement already satisfied: onnxruntime<2.0.0,>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (1.23.2)
# Requirement already satisfied: pyctcdecode<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.5.0)
# Requirement already satisfied: accelerate<1.0.0,>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.34.2)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.23.0)
# Requirement already satisfied: datasets<4.0.0,>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (3.6.0)
# Requirement already satisfied: evaluate<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.4.6)
# Requirement already satisfied: ipykernel<7.0.0,>=6.19.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (6.31.0)
# Requirement already satisfied: jiwer<5.0.0,>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (4.0.0)
# Requirement already satisfied: librosa<1.0.0,>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.11.0)
# Requirement already satisfied: omegaconf<3.0.0,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (2.3.0)
# Requirement already satisfied: soundfile<1.0.0,>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (0.13.1)
# Requirement already satisfied: torch<3.0.0,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (2.9.0+cu126)
# Requirement already satisfied: torchaudio<3.0.0,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (2.9.0+cu126)
# Requirement already satisfied: transformers<5.0.0,>=4.30.0 in /usr/local/lib/python3.12/dist-packages (from tone==0.1.0) (4.57.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate<1.0.0,>=0.26.0->tone==0.1.0) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate<1.0.0,>=0.26.0->tone==0.1.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate<1.0.0,>=0.26.0->tone==0.1.0) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate<1.0.0,>=0.26.0->tone==0.1.0) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=2.14.0->tone==0.1.0) (3.20.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=2.14.0->tone==0.1.0) (22.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=2.14.0->tone==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=2.14.0->tone==0.1.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=2.14.0->tone==0.1.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=2.14.0->tone==0.1.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=2.14.0->tone==0.1.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=2.14.0->tone==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=2.14.0->tone==0.1.0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->tone==0.1.0) (1.2.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (7.34.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (1.6.0)
# Requirement already satisfied: pyzmq>=25 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (26.2.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (5.7.1)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from jiwer<5.0.0,>=3.0.3->tone==0.1.0) (8.3.1)
# Requirement already satisfied: rapidfuzz>=3.9.7 in /usr/local/lib/python3.12/dist-packages (from jiwer<5.0.0,>=3.0.3->tone==0.1.0) (3.14.3)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0.0,>=0.9.2->tone==0.1.0) (1.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf<3.0.0,>=2.3.0->tone==0.1.0) (4.9.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (25.9.23)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (1.14.0)
# Requirement already satisfied: pygtrie<3.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from pyctcdecode<1.0.0,>=0.2.0->tone==0.1.0) (2.5.0)
# Requirement already satisfied: hypothesis<7,>=6.14 in /usr/local/lib/python3.12/dist-packages (from pyctcdecode<1.0.0,>=0.2.0->tone==0.1.0) (6.150.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile<1.0.0,>=0.13.1->tone==0.1.0) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (75.2.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.7.0->tone==0.1.0) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.30.0->tone==0.1.0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.30.0->tone==0.1.0) (0.22.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile<1.0.0,>=0.13.1->tone==0.1.0) (2.23)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=2.14.0->tone==0.1.0) (3.13.2)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from hypothesis<7,>=6.14->pyctcdecode<1.0.0,>=0.2.0->tone==0.1.0) (2.4.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (0.19.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=8.0.0->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (4.5.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa<1.0.0,>=0.9.2->tone==0.1.0) (0.43.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=2.14.0->tone==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=2.14.0->tone==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=2.14.0->tone==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=2.14.0->tone==0.1.0) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa<1.0.0,>=0.9.2->tone==0.1.0) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime<2.0.0,>=1.12.0->tone==0.1.0) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.7.0->tone==0.1.0) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=2.14.0->tone==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=2.14.0->tone==0.1.0) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=2.14.0->tone==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=2.14.0->tone==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=2.14.0->tone==0.1.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=2.14.0->tone==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=2.14.0->tone==0.1.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=2.14.0->tone==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=2.14.0->tone==0.1.0) (1.22.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (0.2.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel<7.0.0,>=6.19.0->tone==0.1.0) (1.17.0)
# Building wheels for collected packages: tone
#   Building editable for tone (pyproject.toml) ... done
#   Created wheel for tone: filename=tone-0.1.0-py3-none-any.whl size=6310 sha256=d1d00ba09824a05135e4b7527677467683066685112a27075d508f5b7fbc12aa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ipult80x/wheels/2e/33/02/4e055370b7a770deee878eff3676794d54bddd7ce115570704
# Successfully built tone
# Installing collected packages: tone
#   Attempting uninstall: tone
#     Found existing installation: tone 0.1.0
#     Uninstalling tone-0.1.0:
#       Successfully uninstalled tone-0.1.0
# Successfully installed tone-0.1.0

# %%
# !python /content/t-one/tone/scripts/export.py \
    --path-to-pretrained /content/tone_ctc \
    --output_path /content/tone_finetuned.onnx
# Out:
# 2026-01-11 00:40:12.188401: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768092012.218711   45758 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768092012.228058   45758 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768092012.286089   45758 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768092012.286125   45758 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768092012.286131   45758 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768092012.286135   45758 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /content/t-one/tone/scripts/export.py:205: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# W0111 00:40:24.029000 45758 torch/onnx/_internal/exporter/_compat.py:114] Setting ONNX exporter to use operator set version 18 because the requested opset_version 17 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# [torch.onnx] Obtain model graph for `ModelToExport([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `ModelToExport([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# WARNING:onnxscript.version_converter:The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 17).
# WARNING:onnxscript.version_converter:Failed to convert the model to the target version 17 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 127, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 122, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnx/version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /github/workspace/onnx/version_converter/adapters/axes_input_to_attribute.h:65: adapt: Assertion `node->hasAttribute(kaxes)` failed: No initializer or constant input to node found
# Applied 198 of general pattern rewrite rules.
# Applied 1 of general pattern rewrite rules.

# %%
from google.colab import files
files.download("/content/tone_finetuned.onnx")

# %%
from google.colab import drive
drive.mount('/content/drive')
